# %% [markdown]
# <a href="https://colab.research.google.com/github/krishbala07/Classifier/blob/main/MobileNet_v2_working_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.applications.mobilenet_v2 import MobileNetV2
import numpy as np
from tensorflow.keras.utils import load_img
from tensorflow.keras.utils import img_to_array
import matplotlib.pyplot as plt
model = MobileNetV2(weights='imagenet')

# %%
image = load_img('/content/sample_data/mouse.jpg', target_size=(224, 224))
image1 = load_img('/content/sample_data/mouse.jpg', target_size=(224, 224))
image = img_to_array(image)
# reshape data for the model
image = image.reshape((1, image.shape[0], image.shape[1], image.shape[2]))
# prepare the image for the VGG model
image = preprocess_input(image)

# %%
predictions = model.predict(image)
print('Shape: {}'.format(predictions.shape))
# Out:
# 1/1 [==============================] - 0s 65ms/step
# Shape: (1, 1000)

# %%
output_neuron = np.argmax(predictions[0])
print('Most active neuron: {} ({:.2f}%)'.format(
    output_neuron,
    100 * predictions[0][output_neuron]
))
# Out:
# Most active neuron: 673 (91.05%)

# %%
from keras.applications.mobilenet_v2 import decode_predictions
plt.imshow(image1)
for name, desc, score in decode_predictions(predictions)[0]:
    print('- {} ({:.2f}%%)'.format(desc, 100 * score))
# Out:
# - mouse (91.05%%)
# - pencil_sharpener (1.90%%)
# - crash_helmet (0.90%%)
# - mousetrap (0.65%%)
# - mountain_tent (0.33%%)
