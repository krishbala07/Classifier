# %% [markdown]
# <a href="https://colab.research.google.com/github/krishbala07/Classifier/blob/main/VGG16_v1_working_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras.utils import load_img
from tensorflow.keras.utils import img_to_array
from keras.applications.vgg16 import preprocess_input
from keras.applications.vgg16 import decode_predictions
from keras.applications.vgg16 import VGG16
# load the model
model = VGG16()
# load an image from file
# Out:
# ...
# 35363/35363 [==============================] - 0s 0us/step
# coffee_mug (85.94%)

# %%
image = load_img('/content/drive/MyDrive/mug.jpg', target_size=(224, 224))
image1 = load_img('/content/drive/MyDrive/mug.jpg', target_size=(224, 224))
# convert the image pixels to a numpy array
image = img_to_array(image)
# reshape data for the model
image = image.reshape((1, image.shape[0], image.shape[1], image.shape[2]))
# prepare the image for the VGG model
image = preprocess_input(image)
# predict the probability across all output classes
yhat = model.predict(image)
# convert the probabilities to class labels
label = decode_predictions(yhat)
# retrieve the most likely result, e.g. highest probability
label = label[0][0]
# print the classification
plt.imshow(image1)
print('%s (%.2f%%)' % (label[1], label[2]*100))
# Out:
# 1/1 [==============================] - 1s 675ms/step
# coffee_mug (85.94%)
