# %% [markdown]
# <a href="https://colab.research.google.com/github/krishbala07/Classifier/blob/main/ResNet50.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://medium.com/@nina95dan/simple-image-classification-with-resnet-50-334366e7311a
#
# https://medium.com/@nutanbhogendrasharma/image-classification-with-resnet50-model-12f4c79c216b
#
# https://www.google.com/url?sa=i&url=https%3A%2F%2Fwww.researchgate.net%2Ffigure%2FThe-five-types-of-ResNet-from-left-18-layers-34-layers-50-layers-101-layers-and_tbl2_329618132&psig=AOvVaw3Z7V8gritMVQcfhmGqbzN8&ust=1673421557975000&source=images&cd=vfe&ved=0CBAQjRxqFwoTCJCvnJ-7vPwCFQAAAAAdAAAAABAp

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from tensorflow.keras.preprocessing import image
from keras.applications.imagenet_utils import preprocess_input
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.utils import img_to_array
from keras.applications.imagenet_utils import decode_predictions
from keras.applications import ResNet50
import matplotlib.pyplot as plt
model = ResNet50(weights='imagenet') 
# 2+9+12+18+9 (layer details)
# Out:
# ...
# 102967424/102967424 [==============================] - 1s 0us/step

# %%
img = image.load_img('/content/sample_data/image.jpg', target_size = (224, 224))

plt.imshow(img)

img = image.img_to_array(img)

img = np.expand_dims(img, axis=0)

img = preprocess_input(img)

# %%
preds = model.predict(img)
print('Predicted:', decode_predictions(preds, top=1)[0][0][1])
# Out:
# 1/1 [==============================] - 0s 242ms/step
# Predicted: Pomeranian
